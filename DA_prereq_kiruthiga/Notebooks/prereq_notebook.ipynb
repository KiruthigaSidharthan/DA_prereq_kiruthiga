# %%
print("hello")
# Out:
# hello

# %% [markdown]
# Hello, my name is Kiruthiga Pitchaimuthu.
# I completed my B.Tech in Information Technology and worked as a Manual Tester at Tata Consultancy Services for one year. After moving to the United States, I took a career break.
# Now I am ready to restart my career and I am interested in Data Analysis. Currently, I have joined Code:You in Louisville to build my skills in this field.
